# %% [markdown]
# Phần 1

# %% [markdown]
# 1. Hãy sắp xếp dữ liệu điểm DH1 theo thứ tự tăng dần

# %%
import pandas as pd
import numpy as np

# %%
df_tuyensinh = pd.read_csv("processed_dulieuxettuyendaihoc.csv")
df_tuyensinh.head(100)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 0     1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.00  7.54  7.01
# 1     2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  4.69  5.47  5.07
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 3     4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  6.21  5.20  6.88
# 4     5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.50  6.36  6.99
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  7.43  7.42  6.83
# 96   97  3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  ...  4.93  5.15  6.39
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
# 98   99  2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  ...  4.15  4.72  5.29
# 99  100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  ...  5.26  5.72  5.85
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %% [markdown]
# 2. Hãy sắp xếp dữ liệu điểm DH2 tăng dần theo nhóm giới tính

# %%
df_tuyensinh.sort_values(by=['GT', 'DH2'], ascending=[True, True])
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  7.43  7.42  6.83
# 25   26  3.6  5.8  6.9  6.1  5.5  7.2  5.5  4.3  4.2  ...  5.40  5.20  5.09
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 46   47  6.7  6.8  6.4  5.9  5.6  6.4  8.0  6.8  6.6  ...  6.49  6.51  6.16
# 13   14  4.9  5.4  5.0  5.0  5.8  7.0  4.2  5.8  4.5  ...  5.38  5.51  6.26
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 68   69  7.3  6.4  6.9  7.5  6.2  8.4  7.6  8.1  8.1  ...  7.19  7.70  8.00
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 47   48  7.9  7.6  8.4  8.6  6.2  7.5  8.7  7.7  7.3  ...  7.67  7.49  7.11
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %% [markdown]
# 3. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT

# %%
def Q1(g):
    return np.percentile(g,25)

# %%
def Q2(g):
    return np.percentile(g,50)

# %%
def Q3(g):
    return np.percentile(g,75)

# %%
def std(g):
    return np.std(g)

# %%
pd.pivot_table(data=df_tuyensinh,index="KT",values="DH1",aggfunc=["sum","mean","median","min","max",std,Q1,Q2,Q3])
# Out:
#        sum      mean median   min   max       std      Q1    Q2     Q3
#        DH1       DH1    DH1   DH1   DH1       DH1     DH1   DH1    DH1
# KT
# A   163.50  3.336735   3.25  1.00  6.50  1.261226  2.2500  3.25  4.250
# A1   17.50  2.916667   3.00  2.00  4.25  0.786165  2.1875  3.00  3.250
# B    29.50  3.277778   3.50  1.75  4.50  0.776785  3.2500  3.50  3.750
# C    79.25  5.660714   5.25  4.75  7.00  0.782665  5.0625  5.25  6.375
# D1   84.25  3.829545   3.75  1.25  6.75  1.338644  3.0000  3.75  4.875

# %% [markdown]
# 4. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT và KV

# %%
pd.pivot_table(data=df_tuyensinh,index=["KT","KV" ],values="DH1",aggfunc=["sum","mean","median","min","max",std,Q1,Q2,Q3])
# Out:
#           sum      mean median   min   max       std      Q1     Q2      Q3
#           DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1     DH1
# KT KV
# A  1    93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250  4.2500
#    2    31.75  3.527778  3.500  2.00  6.25  1.346005  2.2500  3.500  4.2500
#    2NT  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500  4.1250
# A1 1     4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375  2.5625
#    2NT  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250  3.5000
# B  1    25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375  3.5625
#    2NT   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500
# C  1    43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250  5.4375
#    2    11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750  6.1250
#    2NT  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000  6.8125
# ...

# %% [markdown]
# 5. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT, KV và DT

# %%
pd.pivot_table(data=df_tuyensinh,index=["KT","KV","DT"],values="DH1",aggfunc=["sum","mean","median","min","max",std,Q1,Q2,Q3])
# Out:
#               sum      mean median   min   max       std      Q1     Q2  \
#               DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1
# KT KV  DT
# A  1   0.0  93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250
#    2   0.0  27.50  3.437500  3.000  2.00  6.25  1.401729  2.2500  3.000
#        6.0   4.25  4.250000  4.250  4.25  4.25  0.000000  4.2500  4.250
#    2NT 0.0  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500
# A1 1   0.0   4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375
#    2NT 0.0  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250
# B  1   0.0  25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375
#    2NT 0.0   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750
# C  1   0.0  43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250
#    2   0.0  11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750
#    2NT 0.0  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000
# ...

# %% [markdown]
# Phần 2

# %% [markdown]
# 1. Hãy trình bày dữ liệu biến: GT
# Gợi ý
# - Lập bảng tần số và tần suất
# - Vẽ biểu đồ tần số (cột), biểu đồ tần suất (tròn).

# %%
gt=df_tuyensinh.groupby("GT")["GT"].agg("count")

# %%
gt.plot.bar()
# Out:
# <Axes: xlabel='GT'>

# %% [markdown]
# 2. Hãy trình bày dữ liệu lần lượt các biến: US_TBM1, US_TBM2 và US_TBM3

# %%
K22=pd.DataFrame(df_tuyensinh,columns=["US_TBM1","US_TBM2","US_TBM3"])

# %%
K22.describe()
# Out:
#           US_TBM1     US_TBM2    US_TBM3
# count  100.000000  100.000000  100.00000
# mean     2.434480    2.559600    2.67176
# std      0.391203    0.377656    0.29981
# min      1.616000    1.768000    1.91600
# 25%      2.107000    2.223000    2.47300
# 50%      2.480000    2.588000    2.70600
# 75%      2.724000    2.893000    2.87400
# max      3.232000    3.416000    3.31600

# %% [markdown]
# 3. Hãy trình bày dữ liệu biến DT với các học sinh là nam

# %%
dt_nam = df_tuyensinh[df_tuyensinh['GT'] == 'M']['DT']

# %%
dt_nam.value_counts()
dt_nam.value_counts().plot.pie()
plt.show()

# %% [markdown]
# 4. Hãy trình bày dữ liệu biến KV với các học sinh là nam thuộc dân tộc Kinh, có điểm thỏa
# mãn điều kiện (DH1 >= 5.0 và DH2 >= 4.0 và DH3 >= 4.0)

# %%
kv_filtered = df_tuyensinh[(df_tuyensinh['GT'] == 'M') & (df_tuyensinh['DT'] == 0.0) & (df_tuyensinh['DH1'] >= 5.0) & (df_tuyensinh['DH2'] >= 4.0) & (df_tuyensinh['DH3'] >= 4.0)]['KV']

# %%
kv_filtered.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 5. Hãy trình bày dữ liệu lần lượt các biến DH1, DH2, DH3 lớn hơn bằng 5.0 và thuộc khu
# vực 2NT

# %%
dh_filtered = df_tuyensinh[(df_tuyensinh['KV'] == '2NT') &  (df_tuyensinh['DH1'] >= 5.0) & (df_tuyensinh['DH2'] >= 5.0) & (df_tuyensinh['DH3'] >= 5.0)][['DH1', 'DH2', 'DH3']]

# %%
dh_filtered.describe()
# Out:
#         DH1   DH2  DH3
# count  1.00  1.00  1.0
# mean   6.75  5.25  5.0
# std     NaN   NaN  NaN
# min    6.75  5.25  5.0
# 25%    6.75  5.25  5.0
# 50%    6.75  5.25  5.0
# 75%    6.75  5.25  5.0
# max    6.75  5.25  5.0

# %%
dh_filtered.value_counts()
# Out:
# DH1   DH2   DH3
# 6.75  5.25  5.0    1
# Name: count, dtype: int64

# %% [markdown]
# Phần 3: Trực quan hóa dữ liệu theo nhóm phân loại

# %% [markdown]
# 1. Trực quan dữ liệu học sinh nữ trên các nhóm XL1, XL2, XL3 dạng unstacked
# Gợi ý
# - Lọc dữ liệu giới tính là nữ
# - Oy: Chiều cao biểu đồ cột thể hiển số lượng học sinh theo xếp loại
# - Màu sắc thể hiện giá trị xếp loại: [Y, TB, K, G, XS]
# - Ox: thể hiện nhóm XL1, XL2 và XL3

# %%
df_nu = df_tuyensinh[df_tuyensinh['GT'] == 'F']
df_nu[['XL1', 'XL2', 'XL3']].apply(pd.Series.value_counts).T.plot(kind='bar', stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# 2. Trực quan dữ liệu KQXT trên nhóm học sinh có khối thi A, A1, B thuộc khu vực 1, 2

# %%
df_filtered = df_tuyensinh[((df_tuyensinh['KT'] == 'A') | (df_tuyensinh['KT'] == 'A1') | (df_tuyensinh['KT'] == 'B')) & ((df_tuyensinh['KV'] == '1') | (df_tuyensinh['KV'] == '2'))]
df_filtered['KQXT'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='KQXT'>

# %% [markdown]
# 3. Trực quan dữ liệu số lượng thí sinh từng khu vực dựa trên từng nhóm khối thi

# %%
pd.crosstab(df_tuyensinh['KT'], df_tuyensinh['KV']).plot(kind='bar', stacked=False)
# Out:
# <Axes: xlabel='KT'>

# %% [markdown]
# 4. Trực quan dữ liệu số lượng thí sinh đậu, rớt trên từng nhóm khối thi

# %%
pd.crosstab(df_tuyensinh["KT"],df_tuyensinh["KQXT"]).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='KT'>

# %% [markdown]
# 5. Trực quan dữ liệu số lượng thí sinh đậu rớt trên từng nhóm khu vực.

# %%
pd.crosstab(df_tuyensinh["KV"],df_tuyensinh["KQXT"]).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='KV'>

# %% [markdown]
# 6. Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm dân tộc

# %%
pd.crosstab(df_tuyensinh['DT'], df_tuyensinh['KQXT']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='DT'>
